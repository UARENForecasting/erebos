# %%
import xarray as xr
from pathlib import Path
import seaborn as sns
from sklearn import preprocessing
from sklearn.base import RegressorMixin, BaseEstimator
from sklearn.pipeline import Pipeline
from sklearn import linear_model, svm, ensemble, neural_network, decomposition
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from yellowbrick.regressor import residuals_plot, prediction_error

from lightgbm import LGBMRegressor, plot_importance, plot_split_value_histogram

# %%
cdir = Path('/storage/projects/goes_alg/combined/west/daytime/')

# %%
train_ds = xr.open_dataset(cdir /'train_set.nc', engine='h5netcdf')

# %%
yvar = 'cloud_top_altitude'
calipso_mask = train_ds[yvar].values

# %%
def classify(arr):
    # 0 = no, 1 = low, 2 = mid, 3 = high, 4 = deep, 
    narr = np.zeros(arr.shape)
    narr[arr == 8] = 0
    narr[arr < 4] = 1
    narr[(arr == 4) | (arr == 5)] = 2
    narr[arr == 6] = 3
    narr[arr == 7] = 4
    return narr

# %%
vars_ = [v for v in train_ds.variables.keys() if 'CMI_C' in v] + ['cloud_type']
    #'solar_zenith', 'solar_azimuth', 'surface_elevation', 'HT', 'cloud_type']
#vars_ = ['CMI_C12', 'CMI_C04', 'CMI_C07']

# %time df = train_ds[vars_].isel(near=0).to_dataframe()
df = df.drop(columns=[c for c in df.columns if c not in vars_])
if 'cloud_layers' in df.columns and True:
    df['cloud_mask'] = (df['cloud_layers'] > 0).astype(int)
#    df = df.drop(columns=['cloud_layers'])
if 'cloud_type' in vars_:
    df['cloud_type'] = classify(df['cloud_type'].astype(int))
# Out:
# CPU times: user 665 ms, sys: 21.3 ms, total: 686 ms
# Wall time: 688 ms

# %%
import pickle
with open('cloud_mask.pkl', 'rb') as f:
    mask_model = pickle.load(f)
with open('cloud_type.pkl', 'rb') as f:
    type_model = pickle.load(f)

# %%
nans = df.isna().any(axis=1) 
cloud_prob = mask_model.predict_proba(df[~nans].values[:, :-1])
type_probs = type_model.predict_proba(df[~nans].values[:, :-1])
#df['ctype'] = pd.Series(type_model.predict(df[~nans].values[:, :-3]), index=df[~nans].index)
#nans |= pd.Series(cloud_prob == 0, index=df[~nans].index)
#for i, t in enumerate(['low', 'mid', 'high', 'deep']):
#    df[t] = pd.Series(type_probs[:, i] * cloud_prob[:, 1], index=df[~nans].index)
#df['clear'] = pd.Series(cloud_prob[:, 0], index=df[~nans].index)
#nans |= pd.Series(cloud_prob[:, 0] >= 0.5, index=df[~nans].index)
#nans |= pd.Series(train_ds['cloud_layers'].data == 0, index=df.index)
df.shape, nans.sum()
# Out:
# ((341359, 17), 92)

# %%
#nans |= (df['cloud_type'] == 0) 
#nans |= np.isnan(calipso_mask)
X = df[~nans]
y = calipso_mask[X.index]
ynan = np.isnan(y)
if True:
    y[ynan] = 0
else:
    X = X[~ynan]
    y = y[~ynan]
X.shape, y.shape
# Out:
# ((341267, 17), (341267,))

# %%
val_ds = xr.open_dataset(cdir / 'validate_set.nc', engine='h5netcdf')
#limit = (val_ds.cloud_type == 8) | (val_ds.cloud_type == 3)
val_df = val_ds.isel(near=0)[vars_].to_dataframe()#[limit.data]

val_df = val_df.drop(columns=[c for c in val_df.columns if c not in vars_])
if 'cloud_layers' in vars_:# and 'cloud_layers' not in df:
    val_df['cloud_mask'] = (val_df['cloud_layers'] > 0).astype(int)
#    val_df = val_df.drop(columns=['cloud_layers'])
if 'cloud_type' in vars_: 
    val_df['cloud_type'] = classify(val_df.cloud_type)
val_nans = val_df.isna().any(axis=1)  
X_val = val_df[~val_nans][df.columns]
y_val = val_ds[yvar].values[X_val.index]
y_val[np.isnan(y_val)] = 0

# %%
#val_nans |= (val_df['cloud_type'] == 0) 
#val_nans |= np.isnan(val_ds[yvar].values)
tdf = val_df.copy()
tnan = tdf.isna().any(axis=1)
tind = tdf.index[~tnan]
cloud_prob = mask_model.predict_proba(tdf[~tnan].values[:, :-1])
#type_probs = type_model.predict_proba(tdf[~tnan].values[:, :-1])
tdf['cloud_type'] = pd.Series(cloud_prob[:, 1] >= 0.5, index=tind, dtype=float) # 0 clear, 1 cloudy
other = pd.Series(type_model.predict(tdf[~tnan].values[:, :-1]), index=tind)
tdf['cloud_type'] *= other

Xt = tdf[~tnan][df.columns]
yt = val_ds[yvar].values[Xt.index]
ynan = np.isnan(yt)
#ynan |= pd.Series(cloud_prob[:, 0] >=0.5, index=tind)
if True:
    yt[ynan] = 0
else:
    Xt = Xt[~ynan]
    yt = yt[~ynan]

# %%
((tdf['cloud_type'] * other) != 0).sum(), yt[yt > 0].shape
# Out:
# (40856, (40140,))

# %%
class PosMixin(object):
    def predict(self, X, **kwargs):
        out = super().predict(X, **kwargs)
        out[out < 0] = 0
        return out

class PosLGBM(PosMixin, LGBMRegressor):
    pass

class PosMLP(PosMixin, neural_network.MLPRegressor):
    pass

# %%
# reg = LGBMRegressor(boosting_type='gbdt', num_leaves=100, learning_rate=1e-2, n_estimators=500, min_child_weight=1e-4,
#                     min_child_samples=5, max_depth=-1,
#                     reg_alpha=1e-1, reg_lambda=1e-1)
#reg = linear_model.LinearRegression()
#reg = svm.LinearSVR()
#reg = linear_model.Lasso(alpha=0.001)
#reg = ensemble.RandomForestRegressor(max_features=None, n_estimators=100, min_samples_split=10, min_samples_leaf=5, n_jobs=-1)
#reg = ensemble.GradientBoostingRegressor(n_estimators=300, loss='huber', max_depth=5)
#reg = linear_model.ElasticNetCV(max_iter=int(1e6))
reg = neural_network.MLPRegressor(max_iter=1000, verbose=True, activation='relu', alpha=1e-4, hidden_layer_sizes=(50, ),
                                  n_iter_no_change=25, tol=1e-4, solver='adam', beta_1=0.8, beta_2=0.9)
model = Pipeline([
    ('scaler', preprocessing.RobustScaler()),
    ('pca', decomposition.PCA(whiten=True)),
    #('scaler', preprocessing.QuantileTransformer(output_distribution='normal')),
    #('poly', preprocessing.PolynomialFeatures(degree=2, interaction_only=False)),
    ('reg', reg)
])
    
# %time model.fit(X.values, y)
# Out:
# Iteration 1, loss = 1.27957341
# Iteration 2, loss = 0.37970082
# Iteration 3, loss = 0.33854196
# Iteration 4, loss = 0.31018038
# Iteration 5, loss = 0.28447813
# Iteration 6, loss = 0.26715362
# Iteration 7, loss = 0.25448600
# Iteration 8, loss = 0.24435110
# Iteration 9, loss = 0.23659981
# Iteration 10, loss = 0.23050107
# Iteration 11, loss = 0.22516246
# Iteration 12, loss = 0.22064763
# Iteration 13, loss = 0.21710011
# Iteration 14, loss = 0.21460302
# Iteration 15, loss = 0.21234258
# Iteration 16, loss = 0.21054483
# Iteration 17, loss = 0.20888097
# Iteration 18, loss = 0.20763675
# Iteration 19, loss = 0.20669899
# Iteration 20, loss = 0.20574407
# Iteration 21, loss = 0.20495482
# Iteration 22, loss = 0.20423740
# Iteration 23, loss = 0.20352268
# Iteration 24, loss = 0.20268361
# Iteration 25, loss = 0.20196337
# Iteration 26, loss = 0.20149211
# Iteration 27, loss = 0.20117831
# Iteration 28, loss = 0.20069551
# Iteration 29, loss = 0.20021794
# ...

# %%
# %%time
model.score(X, y), model.score(X_val, y_val), model.score(Xt, yt)
# Out:
# CPU times: user 1.35 s, sys: 1.24 s, total: 2.59 s
# Wall time: 459 ms
# (0.9819189433092159, 0.9812348436176668, 0.6385312810805356)

# %%
prediction_error(model, X, y, alpha=0.1)
# Out:
# PredictionError(alpha=0.1,
#                 ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd2e0c3c8>,
#                 bestfit=True, identity=True, is_fitted='auto', model=None,
#                 shared_limits=True)

# %%
prediction_error(model, X_val, y_val, is_fitted=True, alpha=0.1)
# Out:
# PredictionError(alpha=0.1,
#                 ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd2d7e4e0>,
#                 bestfit=True, identity=True, is_fitted='auto', model=None,
#                 shared_limits=True)

# %%
prediction_error(model, Xt, yt, is_fitted=True, alpha=0.1)
# Out:
# PredictionError(alpha=0.1,
#                 ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd2ca9048>,
#                 bestfit=True, identity=True, is_fitted='auto', model=None,
#                 shared_limits=True)

# %%
# %matplotlib inline
residuals_plot(model, X, y, test_size=1e-3, train_alpha=0.1)
# Out:
# ResidualsPlot(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd2fe43c8>,
#               hist=True, is_fitted='auto', line_color=None, model=None,
#               test_alpha=None, test_color=None, train_alpha=None,
#               train_color=None)

# %%
# %matplotlib inline
residuals_plot(model, X_val, y_val, is_fitted=True, test_size=1e-3, train_alpha=0.05)
# Out:
# ResidualsPlot(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd3169c88>,
#               hist=True, is_fitted='auto', line_color=None, model=None,
#               test_alpha=None, test_color=None, train_alpha=None,
#               train_color=None)

# %%
# %matplotlib inline
residuals_plot(model, Xt, yt, is_fitted=True, test_size=1e-3, train_alpha=0.005)
# Out:
# ResidualsPlot(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fabd32f9da0>,
#               hist=True, is_fitted='auto', line_color=None, model=None,
#               test_alpha=None, test_color=None, train_alpha=None,
#               train_color=None)

# %%
import pickle
with open('height.pkl', 'wb') as f:
    pickle.dump(model, f)
